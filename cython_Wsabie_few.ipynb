# %%
import random
import numpy as np
import sys
from random import randint
from data_load import *
from cwsabie_inner import *
from transE_label import *
from gensim.corpora import Dictionary
from collections import Counter
from gensim.models import Word2Vec
from TypeHierarchy import *
# %load_ext cython
# Out:
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %% [markdown]
# # Wsabie

# %%
# %%cython
# import numpy as np
# from TypeHierarchy import *
# cimport numpy as np
# from random import randint
# import sys
# import cython
# cdef extern from "math.h":
#     double sqrt(double m)
# import math
# from libc.stdlib cimport malloc, free
#
# from libc.math cimport exp
# from libc.math cimport log
# from gensim.matutils import argsort
#
# from libc.string cimport memset
# import random
# # scipy <= 0.15
#
# import scipy.linalg.blas as fblas
# ctypedef np.float32_t REAL_t
# cdef int ONE = 1
#
#
# REAL = np.float32
# cdef extern from "/Users/mayk/working/figer/baseline/PLE/Model/warp/voidptr.h":
#     void* PyCObject_AsVoidPtr(object obj)
# DEF MAX_SENTENCE_LEN = 10000
# ctypedef void (*scopy_ptr) (const int *N, const float *X, const int *incX, float *Y, const int *incY) nogil
# ctypedef void (*saxpy_ptr) (const int *N, const float *alpha, const float *X, const int *incX, float *Y, const int *incY) nogil
# ctypedef float (*sdot_ptr) (const int *N, const float *X, const int *incX, const float *Y, const int *incY) nogil
# ctypedef double (*dsdot_ptr) (const int *N, const float *X, const int *incX, const float *Y, const int *incY) nogil
# ctypedef double (*snrm2_ptr) (const int *N, const float *X, const int *incX) nogil
# ctypedef void (*sscal_ptr) (const int *N, const float *alpha, const float *X, const int *incX) nogil
#
#
# cdef scopy_ptr scopy = <scopy_ptr>PyCObject_AsVoidPtr(fblas.scopy._cpointer)  # y = x
# cdef saxpy_ptr saxpy=<saxpy_ptr>PyCObject_AsVoidPtr(fblas.saxpy._cpointer)  # y += alpha * x
# cdef sdot_ptr sdot=<sdot_ptr>PyCObject_AsVoidPtr(fblas.sdot._cpointer)  # float = dot(x, y)
# cdef dsdot_ptr dsdot=<dsdot_ptr>PyCObject_AsVoidPtr(fblas.sdot._cpointer)  # double = dot(x, y)
# cdef snrm2_ptr snrm2=<snrm2_ptr>PyCObject_AsVoidPtr(fblas.snrm2._cpointer)  # sqrt(x^2)
# cdef sscal_ptr sscal=<sscal_ptr>PyCObject_AsVoidPtr(fblas.sscal._cpointer) # x = alpha * x
# DEF EXP_TABLE_SIZE = 10000
# DEF MAX_EXP = 50
#
# cdef REAL_t[EXP_TABLE_SIZE] EXP_TABLE
# cdef REAL_t[EXP_TABLE_SIZE] LOG_TABLE
#
# cdef REAL_t ONEF = <REAL_t>1.0
#
# # for when fblas.sdot returns a double
# cdef REAL_t our_dot_double(const int *N, const float *X, const int *incX, const float *Y, const int *incY) nogil:
#     return <REAL_t>dsdot(N, X, incX, Y, incY)
#
# # for when fblas.sdot returns a float
# cdef REAL_t our_dot_float(const int *N, const float *X, const int *incX, const float *Y, const int *incY) nogil:
#     return <REAL_t>sdot(N, X, incX, Y, incY)
#
# # for when no blas available
# cdef REAL_t our_dot_noblas(const int *N, const float *X, const int *incX, const float *Y, const int *incY) nogil:
#     # not a true full dot()-implementation: just enough for our cases
#     cdef int i
#     cdef REAL_t a
#     a = <REAL_t>0.0
#     for i from 0 <= i < 50 by 1:
#         a += X[i] * Y[i]
#     return a
#
# # for when no blas available
# cdef void our_saxpy_noblas(const int *N, const float *alpha, const float *X, const int *incX, float *Y, const int *incY) nogil:
#     cdef int i
#     for i from 0 <= i < N[0] by 1:
#         Y[i * (incY[0])] = (alpha[0]) * X[i * (incX[0])] + Y[i * (incY[0])]
# cdef REAL_t cvdot(vec1,vec2,size):
#     cdef int csize = size
#     f= dsdot(&csize,<REAL_t *>(np.PyArray_DATA(vec1)),&ONE,<REAL_t *>(np.PyArray_DATA(vec2)),&ONE)
#     return f
# def csaxpy(vec1,vec2,alpha,size):
#     cdef int csize = size
#     cdef float calpha = alpha
#     f= our_saxpy_noblas(&csize,&calpha,<REAL_t *>(np.PyArray_DATA(vec1)),&ONE,<REAL_t *>(np.PyArray_DATA(vec2)),&ONE)
#     return f
# cdef REAL_t crank(int k):
#     cdef REAL_t loss = 0.
#     cdef int i = 1
#     for i in range(1,k+1):
#         loss += ONEF/i
#     return loss
# cdef REAL_t rev_crank(int k):
#     cdef REAL_t loss = 2.
#     cdef int i = 1
#     for i in range(1,k+1):
#         loss -= ONEF/i
#     return loss
# cdef REAL_t vsum(REAL_t *vec,int *size):
#     cdef int i
#     cdef REAL_t product
#     product = <REAL_t>0.0
#     for i from 0 <= i < size[0] by 1:
#         product += vec[i] **2
#     return sqrt(product)
# def cnorm(vec):
#     cdef int size
#     size  = len(vec)
#     return vsum(<REAL_t *>(np.PyArray_DATA(vec)),&size)
# def init():
#     for i in range(EXP_TABLE_SIZE):
#         EXP_TABLE[i] = <REAL_t>exp((i / <REAL_t>EXP_TABLE_SIZE * 2 - 1) * MAX_EXP)
#         EXP_TABLE[i] = <REAL_t>(EXP_TABLE[i] / (EXP_TABLE[i] + 1))
# #init()
#
#
# def ctrain(A,B,insts,size,lr,gradient,it,Verbose=False):
#     cdef float error
#     next_random = 1
#     error = 0.
#    # cdef lam = 0.01
#     for i,inst in enumerate(insts):
#         err,next_random =gradient(A,B,inst,size,next_random,lr=lr)
#
#         error += err
#         if i % 1000 ==0 and Verbose:
#             sys.stdout.write("\rIteration %d " % (it)+ "trained {0:.0f}%".format(float(i)*100/len(insts))+" Loss:{0:.2f}".format(error))
#             sys.stdout.flush()
#     if Verbose:
#         sys.stdout.write("\n")
#     return error
#
# cdef void divide(REAL_t *vec, const float *alpha, const int *size):
#     cdef int i
#     for i from 0 <= i < size[0] by 1:
#         vec[i] = vec[i]/alpha[0]
# def cdivide(vec,alpha):
#     cdef int size
#     size  = len(vec)
#     cdef float r = alpha
#     divide(<REAL_t *>(np.PyArray_DATA(vec)),&r,&size)
#
#
#
#
# def warp_gradient(A,B,inst,size,next_random,lr=0.01):
#     #print B
#     #print B[0]-B[9]
#     cdef unsigned long long  c_next_random = next_random
#     dA = np.zeros(size,dtype=REAL)
#     dB = np.zeros(B.shape,dtype=REAL)
#
#     x = np.sum(A[inst.features],axis=0)
#     cdef REAL_t error = 0.
#     cdef REAL_t clr = lr
#     cdef int N,n_sample
#     cdef int neg_num = len(inst.negative_labels)
#     cdef REAL_t norm
#     cdef int cSize = size
#     cdef REAL_t floats
#     M = len(inst.sparse_labels)
#     for l in inst.sparse_labels:
#         s1 = cvdot(x,B[l],cSize)
#         N = 1
#         n_sample  = -1
#         for k in range(neg_num):
#             c_next_random = random_int32(&c_next_random)
#             nl = inst.negative_labels[c_next_random%neg_num]#randint(0,neg_num-1)]
#             s2 = cvdot(x,B[nl],cSize)
#             if s1 - s2<1:
#                 n_sample = nl
#                 N = k+1
#                 break
#         if n_sample!=-1:
#             L = crank(len(inst.negative_labels)/N)#+rev_crank(i)
#             negL = -L
#             error += (1+s2-s1)*L
#             csaxpy(B[l]-B[n_sample],dA,L,cSize)
#
#             csaxpy(x,dB[l],L,cSize)
#             csaxpy(x,dB[n_sample],-L,cSize)
#     for f in inst.features:
#         csaxpy(dA,A[f],clr,cSize)
#         norm = cnorm(A[f])
#         if norm >1:
#             cdivide(A[f],norm)
#     for i in range(len(B)):
#         csaxpy(dB[i],B[i],clr,cSize)
#         #B[i] += lr*dB[i]
#         norm =  cnorm(B[i])
#         if norm >1:
#             cdivide(B[i],norm)
#             B[i] /=norm
#     return error,c_next_random
#
#
# def save_to_text(matrix,output):
#     shape = matrix.shape
#     with open(output,'wb') as out:
#         out.write("%d %d\n" % (shape))
#         for row in matrix:
#             x = " ".join(map(lambda x:"{0:.5}".format(x),row))
#             out.write(x+"\n")
#
# cdef inline unsigned long long random_int32(unsigned long long *next_random) nogil:
#     next_random[0] = (next_random[0] * <unsigned long long>25214903917ULL + 11) & 281474976710655ULL
#     return next_random[0]
# def crand(sed):
#     cdef unsigned long long csed = sed
#     return random_int32(&csed)
# def save2bin(mat,dct,fn):
#     n,d  = mat.shape
#     with open(fn,'w') as out:
#         out.write("%d %d\n" % (n,d))
#         for i in range(n):
#             text = " ".join(map(str,mat[i]))
#             out.write("%s %s\n" %(dct[i],text))
# def normalize(mat):
#     for v in mat:
#         norm = np.linalg.norm(v)
#         if norm >=1:
#             v /= norm
# def refine(labels,type_hierarchy,maxDepth=2,delim='/'):
#     results = []
#     labels = [labels[i] for i in range(len(labels))]
#     pathes = [ type_hierarchy.get_type_path(labels[i]) for i in range(len(labels))]
#     for i in range(len(labels)):
#         for k in range(len(pathes[i])):
#             if len(results)<k+1:
#                 results.append(pathes[i][k])
#             elif results[-1]!=pathes[i][k]:
#                 break
#     return results
#
# def refine_data(A,B,data,tier):
#     for inst in data:
#         inst.sparse_labels = test(A,B,tier,inst)
#
#
# def test(A,B,tier,inst,topk=3):
#     cdef int cSize = B.shape[1]
#     x = np.sum(A[inst.features],axis=0)
#
#     scores = [cvdot(x,B[l],cSize) for l in inst.old_labels]
#     ranks = argsort(scores,reverse=True)
#     return refine([inst.old_labels[r] for r in ranks],tier)

# %%
in_dir= "/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN"
a=MentionData('/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/train_x_new.txt',
              "/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/train_y.txt",
             in_dir+"/feature.txt",in_dir+"/type.txt")
label_bin  = Word2Vec.load_word2vec_format('/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/labels.bin')
label_bin_hier  = Word2Vec.load_word2vec_format('/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/labels_hier.bin')
#label_bin  = Word2Vec.load_word2vec_format('/Users/mayk/working/figer/baseline/PLE/Model/warp/embedding/BBN/inter_l2v_300.txt')

# %%
np.random.seed(12)
size= 300
# A= np.random.uniform(-6/np.sqrt(size),6/np.sqrt(size), [len(a.feature2id),size]).astype(np.float32)#np.random.rand(len(a.feature2id),size).astype(np.float32)
# B = np.random.uniform(-6/np.sqrt(size),6/np.sqrt(size), [len(a.label2id),size]).astype(np.float32)

A= np.random.normal(0,1, [len(a.feature2id),size]).astype(np.float32)#np.random.rand(len(a.feature2id),size).astype(np.float32)
B = np.random.normal(0,1, [len(a.label2id),size]).astype(np.float32)
# B =np.asarray([label_bin[a.id2label[i]] for i in range(len(label_bin.vocab))],dtype=np.float32)#np.random.normal(0,1.0, [len(a.label2id),size]).astype(np.float32)
# B_0 = np.asarray([label_bin[a.id2label[i]] for i in range(len(label_bin.vocab))],dtype=np.float32)
next_random = 1
normalize(A)
normalize(B)
# normalize(B_0)

tier= TypeHierarchy('../../Intermediate/BBN/supertype.txt',B.shape[0])
for i in range(15): 
    reg_err =0.
    #B-=0.15*(B-C)
    ctrain(A,B,a.data,size,0.0001,warp_gradient,it=i,Verbose=True)
#     B -= 0.1*(B-B_0)
   # refine_data(A,B,a.data,tier)

save2bin(A,a.id2feature,'/Users/mayk/working/figer/baseline/PLE/Results/BBN/warp_A.bin')
save2bin(B,a.id2label,'/Users/mayk/working/figer/baseline/PLE/Results/BBN/warp_B.bin')
# Out:
# Iteration 0 trained 100% Loss:132341.59
# Iteration 1 trained 100% Loss:96204.81
# Iteration 2 trained 100% Loss:84683.83
# Iteration 3 trained 100% Loss:78706.80
# Iteration 4 trained 100% Loss:74197.63
# Iteration 5 trained 100% Loss:70676.70
# Iteration 6 trained 100% Loss:68247.45
# Iteration 7 trained 100% Loss:65032.10
# Iteration 8 trained 100% Loss:62909.67
# Iteration 9 trained 100% Loss:61420.54
# Iteration 10 trained 100% Loss:59267.98
# Iteration 11 trained 100% Loss:57682.50
# Iteration 12 trained 100% Loss:56354.81
# Iteration 13 trained 100% Loss:55558.03
# Iteration 14 trained 100% Loss:54043.05

# %%
save2bin(A,a.id2feature,'/Users/mayk/working/figer/baseline/PLE/Results/warp_A.bin')
save2bin(B,a.id2label,'/Users/mayk/working/figer/baseline/PLE/Results/warp_B.bin')

# %%
B = np.zeros([len(a.label2id),300+label_bin_hier.syn0.shape[1]])

# %%
translate(test(A,B,tier,a.data[1]))
# Out:
# ['/ORGANIZATION', '/ORGANIZATION/CORPORATION']

# %%
translate = lambda x: map(lambda y:a.id2label[y],x)

# %%
def filte_rare(data,labels):
    
    new_data = []
    ids = []
    for i in range(len(data)):
        skip = False
        for l in data[i].sparse_labels:
            if l in labels:
                skip =True
                break
        if not skip:
            ids.append(i)
            new_data.append(data[i])
    return ids,new_data
def keep_rare(data,labels):
    
    new_data = []
    for i in range(len(data)):
        skip = False
        for l in data[i].sparse_labels:
            if l in labels:
                skip =True
                break
        if skip:
            new_data.append(data[i])
    return new_data

# %%
rare_labels = set()
d = [0]*len(a.label2id)
for inst in a.data:
    for l in inst.sparse_labels:
        d[l]+=1
for i in range(len(d)):
    if d[i] < 500:
        print a.id2label[i]
        rare_labels.add(i)
ids,a.data= filte_rare(a.data,rare_labels)
# Out:
# /ANIMAL
# /GAME
# /ORGANIZATION/HOSPITAL
# /FACILITY/ATTRACTION
# /PRODUCT/WEAPON
# /FACILITY/HIGHWAY_STREET
# /LOCATION/CONTINENT
# /ORGANIZATION/MUSEUM
# /FACILITY/BUILDING
# /FACILITY/BRIDGE
# /WORK_OF_ART/PLAY
# /LAW
# /EVENT/HURRICANE
# /PRODUCT/VEHICLE
# /LOCATION/RIVER
# /FACILITY/AIRPORT
# /ORGANIZATION/HOTEL
# /ORGANIZATION/RELIGIOUS
# /LOCATION/LAKE_SEA_OCEAN

# %%
in_dir= "/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN"
test=MentionData('/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/test_x.txt',
              "/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/test_y.txt",
             in_dir+"/feature.txt",in_dir+"/type.txt")

# %%
rare_labels = set()
d = [0]*len(a.label2id)
for inst in a.data:
    for l in inst.sparse_labels:
        d[l]+=1
for i in range(len(d)):
    if d[i] < 5000:
        rare_labels.add(i)
with open('/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/mention.txt') as mentions:
    mention_dict = dict()
    for ln in mentions:
        splited = ln.rstrip().split()
        mention_dict[splited[0]] = splited[1]
ids,test.data = filte_rare(test.data,[l for l in range(len(test.label2id)) if l not in rare_labels])
origin_ids = [ ln.rstrip().split()[0] for ln in open('/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/test_x.txt')]

# %%
with open('/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/mention_type_zero.txt','w') as rare,open('/Users/mayk/working/figer/baseline/PLE/Intermediate/BBN/test_x_zero.txt','w') as x:
    for i,inst in enumerate(test.data):
        x.write("%s\t%s\n" % (origin_ids[ids[i]],",".join(map(str,inst.features))))
        for l in inst.sparse_labels:
            rare.write("%s\t%d\t%d\n" %(mention_dict[origin_ids[ids[i]]],l,1))

# %%
translate(a.data[0].sparse_labels)
translate(test(A,B,tier,a.data[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8cc5679ddbd8> in <module>()
# ----> 1 translate(a.data[0].sparse_labels)
#       2 translate(test(A,B,tier,a.data[0]))
#
# NameError: name 'translate' is not defined

# %%
tier= TypeHierarchy('../../Intermediate/BBN/supertype.txt',B.shape[0])
roots = set([i for i in range(len(a.label2id)) if tier.get_type_path(i)[0] == i])

for inst in a.data:
    labels = set()
    for l in inst.sparse_labels:
        path= tier.get_type_path(l)
        labels.add(path[0])
    labels = list(labels)
    inst.sparse_labels = labels
    inst.negative_labels = [ l for l in roots if l not in inst.sparse_labels]
#     full_labels = np.zeros(len(a.id2label),dtype=float)
#     full_labels[labels]=1.
#     a.data[i]=Instance(a.data[i].features,full_labels,labels)

# %%
for inst in a.data[:1000]:
    print translate(inst.sparse_labels)
# Out:
# ['/PLANT', '/PRODUCT', '/SUBSTANCE']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/DISEASE']
# ['/PLANT', '/PRODUCT', '/SUBSTANCE']
# ['/PLANT', '/ANIMAL']
# ['/GAME']
# ['/SUBSTANCE']
# ['/ORGANIZATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PLANT', '/ANIMAL']
# ['/PLANT']
# ['/LOCATION']
# ['/SUBSTANCE']
# ['/PLANT', '/PRODUCT', '/SUBSTANCE']
# ['/EVENT']
# ['/GPE', '/LOCATION']
# ['/SUBSTANCE']
# ['/PERSON']
# ['/EVENT']
# ['/DISEASE']
# ['/DISEASE']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/PERSON']
# ['/LOCATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/GPE']
# ['/DISEASE']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/PLANT']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/GPE', '/LOCATION', '/ORGANIZATION']
# ['/PLANT', '/ANIMAL']
# ['/GPE']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/GPE']
# ['/EVENT']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/FACILITY', '/GPE']
# ['/PERSON']
# ['/PLANT']
# ['/EVENT']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/EVENT']
# ['/EVENT']
# ['/WORK_OF_ART']
# ['/EVENT']
# ['/PLANT', '/SUBSTANCE']
# ['/EVENT']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/WORK_OF_ART']
# ['/FACILITY', '/GPE']
# ['/GPE']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/GPE', '/LOCATION']
# ['/GPE', '/LOCATION', '/ORGANIZATION']
# ['/PLANT', '/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PLANT', '/PRODUCT', '/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE']
# ['/GPE', '/LOCATION']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/LOCATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/DISEASE']
# ['/GPE']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/GPE']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/ORGANIZATION']
# ['/GPE']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/EVENT']
# ['/EVENT']
# ['/GPE']
# ['/GPE']
# ['/GPE']
# ['/GPE']
# ['/GPE']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/GPE']
# ['/GPE']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/GPE']
# ['/GPE']
# ['/GPE', '/LOCATION']
# ['/GPE']
# ['/GPE']
# ['/GPE', '/LOCATION', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/GPE', '/LOCATION']
# ['/GPE', '/LOCATION']
# ['/GPE', '/LOCATION']
# ['/GPE']
# ['/PERSON']
# ['/GPE']
# ['/PERSON']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PLANT']
# ['/ORGANIZATION']
# ['/LANGUAGE']
# ['/SUBSTANCE']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/SUBSTANCE']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/EVENT']
# ['/LANGUAGE']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/EVENT']
# ['/PLANT']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PLANT']
# ['/WORK_OF_ART']
# ['/PERSON', '/ORGANIZATION']
# ['/PLANT']
# ['/PLANT']
# ['/PERSON', '/ORGANIZATION']
# ['/SUBSTANCE']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/GPE']
# ['/EVENT']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PLANT']
# ['/PERSON']
# ['/PERSON']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/GPE']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/GPE']
# ['/SUBSTANCE']
# ['/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PRODUCT']
# ['/GPE', '/PERSON']
# ['/PRODUCT']
# ['/PRODUCT', '/SUBSTANCE']
# ['/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/EVENT']
# ['/SUBSTANCE']
# ['/SUBSTANCE']
# ['/SUBSTANCE']
# ['/PRODUCT']
# ['/PRODUCT', '/SUBSTANCE']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/DISEASE']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PLANT']
# ['/FACILITY']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PLANT']
# ['/PLANT', '/ANIMAL']
# ['/PLANT']
# ['/PRODUCT']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PLANT']
# ['/PRODUCT', '/SUBSTANCE']
# ['/ORGANIZATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/DISEASE']
# ['/PLANT']
# ['/PRODUCT', '/SUBSTANCE']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PLANT']
# ['/PLANT']
# ['/PERSON']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/LOCATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PLANT', '/ANIMAL']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/GPE']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/DISEASE']
# ['/EVENT']
# ['/PERSON']
# ['/PERSON']
# ['/PRODUCT', '/SUBSTANCE']
# ['/GAME']
# ['/PRODUCT', '/SUBSTANCE']
# ['/SUBSTANCE']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/GPE']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/EVENT']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/EVENT']
# ['/WORK_OF_ART']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/GPE', '/LOCATION']
# ['/GPE', '/LOCATION']
# ['/GPE', '/LOCATION', '/ORGANIZATION']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/DISEASE']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/GPE']
# ['/EVENT']
# ['/PERSON']
# ['/PLANT', '/ANIMAL']
# ['/PERSON']
# ['/PERSON']
# ['/PRODUCT']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/SUBSTANCE']
# ['/PERSON']
# ['/PRODUCT']
# ['/PERSON']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/PERSON']
# ['/GAME']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON']
# ['/LOCATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/GPE']
# ['/SUBSTANCE']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/GPE']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/GAME']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/DISEASE']
# ['/PERSON']
# ['/PERSON']
# ['/GPE']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/DISEASE']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/EVENT']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PLANT', '/ANIMAL']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/PERSON']
# ['/PERSON']
# ['/EVENT']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/PRODUCT', '/SUBSTANCE']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/DISEASE']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/EVENT']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PLANT', '/SUBSTANCE']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/PLANT', '/SUBSTANCE']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/SUBSTANCE']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/SUBSTANCE']
# ['/LOCATION']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/GPE']
# ['/DISEASE']
# ['/FACILITY', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/EVENT']
# ['/PERSON']
# ['/PERSON']
# ['/EVENT']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/CONTACT_INFO']
# ['/SUBSTANCE']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/GPE']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/EVENT']
# ['/WORK_OF_ART']
# ['/GPE']
# ['/EVENT']
# ['/GPE']
# ['/EVENT']
# ['/WORK_OF_ART']
# ['/DISEASE']
# ['/LANGUAGE']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PLANT', '/ANIMAL']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/GPE']
# ['/SUBSTANCE']
# ['/SUBSTANCE']
# ['/EVENT']
# ['/PLANT']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/EVENT']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/EVENT']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/EVENT']
# ['/LANGUAGE']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/CONTACT_INFO']
# ['/PLANT']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/GPE']
# ['/GPE']
# ['/PERSON']
# ['/GPE']
# ['/GAME']
# ['/EVENT']
# ['/GPE']
# ['/GPE']
# ['/SUBSTANCE']
# ['/PERSON']
# ['/EVENT']
# ['/EVENT']
# ['/GPE']
# ['/PERSON']
# ['/EVENT']
# ['/EVENT']
# ['/PERSON']
# ['/GPE']
# ['/EVENT']
# ['/GPE']
# ['/SUBSTANCE']
# ['/PERSON']
# ['/LOCATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/GPE']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/GPE']
# ['/PRODUCT']
# ['/PERSON']
# ['/EVENT']
# ['/GPE']
# ['/GPE']
# ['/PERSON']
# ['/LOCATION']
# ['/GPE']
# ['/LOCATION']
# ['/GPE']
# ['/GPE']
# ['/DISEASE']
# ['/EVENT']
# ['/GPE']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/GPE']
# ['/GPE']
# ['/PERSON']
# ['/GPE']
# ['/PERSON']
# ['/GPE']
# ['/GPE']
# ['/GPE']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE']
# ['/GPE']
# ['/PERSON']
# ['/EVENT']
# ['/WORK_OF_ART']
# ['/EVENT']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE']
# ['/PERSON']
# ['/GPE']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/GPE']
# ['/DISEASE']
# ['/GPE', '/LOCATION']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/PLANT', '/ANIMAL']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION', '/EVENT']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION', '/EVENT']
# ['/ORGANIZATION']
# ['/GPE']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/SUBSTANCE']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/CONTACT_INFO']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/PLANT']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/LANGUAGE']
# ['/PERSON']
# ['/GPE', '/LOCATION', '/ORGANIZATION']
# ['/LOCATION']
# ['/FACILITY']
# ['/GPE']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/EVENT']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/EVENT']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/GPE', '/LOCATION']
# ['/GPE']
# ['/EVENT']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/LOCATION']
# ['/EVENT']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON']
# ['/PLANT']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/GPE']
# ['/PERSON']
# ['/PERSON']
# ['/EVENT']
# ['/PERSON']
# ['/EVENT']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/PLANT', '/PRODUCT', '/SUBSTANCE']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/FACILITY']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/GPE']
# ['/GPE']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/GPE']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/SUBSTANCE']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/EVENT']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/CONTACT_INFO']
# ['/EVENT']
# ['/PERSON']
# ['/EVENT']
# ['/ORGANIZATION']
# ['/EVENT']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/PERSON']
# ['/EVENT']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/GPE', '/LOCATION']
# ['/GPE']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON']
# ['/GPE']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/EVENT']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/EVENT']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/LOCATION']
# ['/EVENT']
# ['/PERSON']
# ['/GPE']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/EVENT']
# ['/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/EVENT']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/PERSON', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/GPE']
# ['/ORGANIZATION']
# ['/GPE']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE']
# ['/GPE', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/LAW']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE']
# ['/PERSON']
# ['/PERSON']
# ['/EVENT']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PLANT']
# ['/GPE']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART']
# ['/GPE', '/LOCATION']
# ['/PERSON']
# ['/PERSON']
# ['/GPE']
# ['/WORK_OF_ART']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/GAME']
# ['/PLANT']
# ['/GPE']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/PERSON']
# ['/EVENT']
# ['/GPE']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/GPE']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/GPE', '/LOCATION']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/WORK_OF_ART']
# ['/ORGANIZATION']
# ['/WORK_OF_ART', '/CONTACT_INFO']
# ['/EVENT']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON']
# ['/PLANT']
# ['/GAME']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON']
# ['/PERSON']
# ['/LANGUAGE']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/GPE']
# ['/PERSON']
# ['/PERSON']
# ['/GPE']
# ['/WORK_OF_ART']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/GPE', '/LOCATION']
# ['/WORK_OF_ART']
# ['/PERSON']
# ['/PERSON', '/ORGANIZATION']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/WORK_OF_ART']
# ['/WORK_OF_ART']
# ['/PERSON', '/ORGANIZATION']
# ['/PERSON']
# ['/WORK_OF_ART', '/ORGANIZATION']
# ['/PERSON']
# ['/ORGANIZATION']
# ['/ORGANIZATION']
# ['/PERSON']

# %%
b
# Out:
# [18, 17, 19]
